# %%
# %load_ext autoreload
# %autoreload 3 -p

# %%
import sys
import logging
import numpy as np
import xarray as xr
import pandas as pd

import holoviews as hv
import colorcet as cc
from holoviews import opts

from tqdm_joblib import ParallelPbar
from joblib import delayed

from gnss_tid.pointdata import PointData
from gnss_tid.old_pointdata import PointData as old_PointData

hv.extension("bokeh")
opts.defaults(
    opts.Image(data_aspect=1, frame_height=300, frame_width=500, cmap=cc.cm.coolwarm, colorbar=True, show_grid=True, tools=["hover"]),
    hv.opts.Scatter(data_aspect=1, frame_height=300, frame_width=500, cmap=cc.cm.coolwarm, colorbar=True, show_grid=True, tools=["hover"]),
)
logging.basicConfig(stream=sys.stdout)
logging.root.setLevel(logging.INFO)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='faeb409d-3c6c-473b-b850-685a8f860e10'>
#   <div id="c752568d-02d9-497e-a83d-221fe68438c7" data-root-id="faeb409d-3c6c-473b-b850-685a8f860e10" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"ba7d967d-9577-47ba-a120-9e4a9b2c1196":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"7167290a-9b05-48a4-9e49-8e298a236f07","attributes":{"notifications":{"type":"object","name":"Notifications","id":"81ba599e-0d10-4101-b4f8-7052357bed1b"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"faeb409d-3c6c-473b-b850-685a8f860e10"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"13714a3d-32d9-49df-a09f-a9c1a3d54f88","attributes":{"plot_id":"faeb409d-3c6c-473b-b850-685a8f860e10","comm_id":"31729f0d6e444069a7856a30580d102a","client_comm_id":"869e7a59f55c4027b8de7dd0482be86c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"ba7d967d-9577-47ba-a120-9e4a9b2c1196","roots":{"faeb409d-3c6c-473b-b850-685a8f860e10":"c752568d-02d9-497e-a83d-221fe68438c7"},"root_ids":["faeb409d-3c6c-473b-b850-685a8f860e10"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.22.1">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.8.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>

# %%
time_limits = ["20150325_234000", "20150325_235200"]
latitude_limits = [24, 48]
longitude_limits = [-120, -75]
TI = 5
HEIGHT = 200
WINDOW = 4
STEP = 2

# %%
print("LOADING NEW DATA")

new = {}
new["points"] = PointData(
  "/disk1/tid/2015/0325/*.nc",
  latitude_limits=latitude_limits,
  longitude_limits=longitude_limits,
  time_limits=time_limits,
  el_min=30,
)
new["time_slices"], new["times"] = new["points"].get_time_slices(WINDOW, STEP)
# Out:
# LOADING NEW DATA
# INFO:root:loading files
# loading files:   0%|          | 0/3916 [00:00<?, ?it/s]
# INFO:root:files n_rejected = 1039
# INFO:root:file 26.53% reject rate
# INFO:root:combining files
# INFO:root:data ready

# %%
hours_in_files = 30
minutes = 12.5

print(f"expected time ratio = {minutes/(hours_in_files*60)}")
valid = new["points"].debug_table.valid_sum.sum()
n_sv = new["points"].debug_table.unique_valid_svs.apply(lambda x: x.size)
valid_per_sv = valid / n_sv.sum()
print(f"{valid_per_sv = }")
print(f"valid per sv per min = {valid_per_sv / minutes}")

time_valid_ratio_expected = (new["points"].debug_table.valid_time_mean >= (minutes/(hours_in_files*60))).mean()
print(f"{time_valid_ratio_expected = }")

all_svs = np.unique(np.concat(new["points"].debug_table.unique_svs.values))
filtered_svs = np.unique(np.concat(new["points"].debug_table.unique_valid_svs.values))
missing_svs = all_svs[~np.isin(all_svs, filtered_svs)]
print("num svs within time limits ", filtered_svs.shape[0])
print("num svs in all files ", all_svs.shape[0])

print("any missing time/el/az in any file?", new["points"].debug_table.fin_mask_mean.min() < 1)


for v in ["dtec0", "dtec1", "dtec2", "dtec3", "dtecp"]:
    null_sum = new["points"].debug_table[f"{v}_null_sum"].sum()
    print(f"{v} null sum = {null_sum}")
    print(f"{v} null rate = {null_sum / valid}")

new["points"].debug_table.drop(columns=["unique_valid_svs", "unique_svs"])
# Out:
# expected time ratio = 0.006944444444444444
# valid_per_sv = np.float64(23.48330804248862)
# valid per sv per min = 1.8786646433990897
# time_valid_ratio_expected = np.float64(0.9294403892944039)
# num svs within time limits  13
# num svs in all files  31
# any missing time/el/az in any file? False
# dtec0 null sum = 661
# dtec0 null rate = 0.001779694786382777
# dtec1 null sum = 12542
# dtec1 null rate = 0.03376842966840059
# dtec2 null sum = 20821
# dtec2 null rate = 0.05605903955714947
# dtec3 null sum = 28068
# dtec3 null rate = 0.07557106393977578
# dtecp null sum = 810
# dtecp null rate = 0.0021808665309683045
#       valid_mean  valid_sum  invalid_sum  fin_mask_mean  fin_mask_sum  \
# cmp9    0.003883        121     0.996117            1.0         31158
# abrn    0.003888        120     0.996112            1.0         30867
# bepk    0.004113        125     0.995887            1.0         30393
# al50    0.003338        100     0.996662            1.0         29956
# asub    0.005248        157     0.994752            1.0         29916
# ...          ...        ...          ...            ...           ...
# nysm    0.008514        120     0.991486            1.0         14094
# pck5    0.004504        103     0.995496            1.0         22868
# ncco    0.007060        165     0.992940            1.0         23371
# vtri    0.008620        124     0.991380            1.0         14385
# pur5    0.006119        170     0.993881            1.0         27781
#
#       valid_time_mean  valid_time_sum  invalid_time_sum  valid_el_mean  \
# cmp9         0.007446             232             30926       0.582772
# abrn         0.008909             275             30592       0.549908
# bepk         0.007600             231             30162       0.581548
# al50         0.007745             232             29724       0.601415
# asub         0.009192             275             29641       0.614788
# ...               ...             ...               ...            ...
# nysm         0.017241             243             13851       0.605648
# pck5         0.009839             225             22643       0.573203
# ncco         0.011767             275             23096       0.612811
# vtri         0.016406             236             14149       0.610288
# pur5         0.008927             248             27533       0.595371
#
#       valid_el_sum  ...  dtec0_null_sum  dtec0_null_mean  dtec1_null_sum  \
# cmp9         18158  ...               0            0.000               0
# abrn         16974  ...               0            0.000               0
# bepk         17675  ...               0            0.000               0
# al50         18016  ...               0            0.000               0
# asub         18392  ...               0            0.000               0
# ...            ...  ...             ...              ...             ...
# nysm          8536  ...              45            0.375             120
# pck5         13108  ...               0            0.000              67
# ncco         14322  ...               0            0.000             111
# vtri          8779  ...               0            0.000               0
# pur5         16540  ...               0            0.000               0
#
#       dtec1_null_mean  dtec2_null_sum  dtec2_null_mean  dtec3_null_sum  \
# cmp9         0.000000               0              0.0               0
# abrn         0.000000               0              0.0               2
# bepk         0.000000               0              0.0               0
# al50         0.000000               0              0.0               0
# asub         0.000000               0              0.0               1
# ...               ...             ...              ...             ...
# nysm         1.000000             120              1.0             120
# pck5         0.650485             103              1.0             103
# ncco         0.672727             165              1.0             165
# vtri         0.000000               0              0.0               0
# pur5         0.000000               0              0.0               0
#
#       dtec3_null_mean  dtecp_null_sum  dtecp_null_mean
# cmp9         0.000000               0            0.000
# abrn         0.016667               0            0.000
# bepk         0.000000               0            0.000
# al50         0.000000               0            0.000
# asub         0.006369               0            0.000
# ...               ...             ...              ...
# nysm         1.000000              15            0.125
# pck5         1.000000               0            0.000
# ncco         1.000000               0            0.000
# vtri         0.000000               0            0.000
# pur5         0.000000               0            0.000
#
# [2877 rows x 24 columns]

# %%
print("LOADING OLD DATA")

old = {}
old["points"] = old_PointData(
    ["/disk1/tid/data/2015_0325T0000-0326T0000_all0325.yaml_30el_30s_ra.h5"],
    latitude_limits=latitude_limits,
    longitude_limits=longitude_limits,
    time_limits=time_limits,
)
old["time_slices"], old["times"] = old["points"].get_time_slices(WINDOW, STEP)
# Out:
# LOADING OLD DATA

# %%
new["data"] = new["points"].get_data(new["time_slices"][TI], HEIGHT)
new["data"]
# Out:
# Reloading 'gnss_tid.pointdata'.
# Reloading 'gnss_tid.old_pointdata'.
# INFO:root:points in time range: 59812
# INFO:root:time range: 2015-03-25T23:45:00.000000000, 2015-03-25T23:46:30.000000000
# <xarray.Dataset> Size: 1MB
# Dimensions:    (los_id: 10846)
# Coordinates:
#   * los_id     (los_id) int64 87kB 0 1 2 3 4 5 ... 15800 15801 15802 15803 15807
#     x          (los_id) float64 87kB -1.862e+03 -1.93e+03 ... 1.776e+03
#     y          (los_id) float64 87kB 97.14 -180.7 154.6 ... -103.5 1.341e+03
# Data variables: (12/13)
#     az         (los_id) float64 87kB 49.77 158.8 57.38 ... 315.5 134.6 307.4
#     el         (los_id) float64 87kB 59.54 41.55 31.0 ... 38.99 30.35 40.92
#     dtec0      (los_id) float64 87kB -0.007631 0.01464 ... 0.02005 0.009673
#     dtec1      (los_id) float64 87kB -0.1475 0.08483 0.003861 ... nan -0.04698
#     dtec2      (los_id) float64 87kB -0.2494 0.151 -0.1202 ... nan nan -0.01723
#     dtec3      (los_id) float64 87kB -0.3832 0.197 -0.2367 ... nan nan 0.03357
#     ...         ...
#     tec_noise  (los_id) float64 87kB 2.815 3.946 3.051 ... 6.891 9.571 3.449
#     tec_snr    (los_id) float64 87kB 51.25 47.75 46.0 50.75 ... 47.57 42.85 47.5
#     rx         (los_id) int64 87kB 0 0 0 0 0 1 ... 2874 2874 2874 2874 2874 2875
#     sv         (los_id) object 87kB 'G07' 'G09' 'G19' ... 'G30' 'G04' 'G30'
#     lat        (los_id) float32 43kB 35.01 32.55 35.82 ... 36.86 33.35 45.59
#     lon        (los_id) float32 43kB -117.5 -117.6 -115.5 ... -78.13 -75.24
# Attributes:
#     time:     2015-03-25T23:45:00.000000000
#     height:   200

# %%
old["data"] = old["points"].get_data(old["time_slices"][TI], HEIGHT)
old["data"]
# Out:
# Reloading 'gnss_tid.old_pointdata'.
# INFO:root:points in time range: Frozen({'time': 4, 'prn': 29, 'rx': 2972, 'geo': 3})
# INFO:root:time range: 2015-03-25T23:45:00.000000000, 2015-03-25T23:46:30.000000000
# <xarray.Dataset> Size: 1MB
# Dimensions:   (los: 11208)
# Coordinates:
#     rx        (los) <U10 448kB '1lsu' '1lsu' '1lsu' ... 'ztl4' 'ztl4' 'ztl4'
#     prn       (los) int64 90kB 6 7 9 17 27 6 7 9 17 27 ... 27 6 7 17 6 7 9 17 27
#     quantile  float64 8B 0.998
# Dimensions without coordinates: los
# Data variables:
#     az        (los) float64 90kB 358.0 205.6 139.6 51.05 ... 151.4 52.12 317.7
#     el        (los) float64 90kB 68.47 45.3 40.34 50.96 ... 41.37 59.0 39.78
#     tec       (los) float64 90kB 0.1749 -0.05333 0.08524 ... 0.0281 0.008425
#     lat       (los) float64 90kB 31.09 28.87 28.87 31.28 ... 31.66 34.01 34.88
#     lon       (los) float64 90kB -91.22 -92.03 -89.7 ... -83.22 -83.32 -86.0
#     x         (los) float64 90kB 617.5 550.7 784.7 ... 1.344e+03 1.08e+03
#     y         (los) float64 90kB -523.4 -782.8 -768.2 ... -378.3 -111.4 -44.91
# Attributes:
#     time:     2015-03-25T23:45:00.000000000
#     height:   200

# %%
svs_old, counts_old = np.unique_counts(old["data"].prn)
svs_new, counts_new = np.unique_counts(new["data"].sv)

(
    hv.Bars(
        (svs_old, counts_old), kdims="prn"
    ).opts(width=500, height=400, show_grid=True, bar_width=1.5).relabel("old")
    + hv.Bars(
        (svs_new, counts_new), kdims="sv"
    ).opts(width=500, height=400, show_grid=True).relabel("new")
)
# Out:
# :Layout
#    .Bars.Old :Bars   [prn]   (y)
#    .Bars.New :Bars   [sv]   (y)

# %%
from gnss_tid.image import ScipyRbfImageMaker

TECVAR = "dtecp"

image_maker = ScipyRbfImageMaker(
    hres=20,
    hp_freq=.02,
    neighbor_radius=100.0,
    neighbors=50,
    kernel="multiquadric",
    smoothing=.2,
)
b = {
    "west": -2224.88,
    "south": -1326.55,
    "east": 2231.40,
    "north": 1614.67,
}
image_maker.initialize(old["data"].x.values, None, b)


old["img"] = image_maker(old["data"].x.values, old["data"].y.values, old["data"].tec.values)
new["img"] = image_maker(new["data"].x.values, new["data"].y.values, new["data"][TECVAR].values)

old_pts = np.isfinite(old["data"].tec.values).sum()
new_pts = np.isfinite(new["data"][TECVAR].values).sum()

cmap = cc.cm.diverging_bwr_20_95_c54
(
    hv.Scatter(
        old["data"].to_dataframe(), kdims="x", vdims=["y", "tec"]
    ).opts(size=5, clim=(-.4, .4), cmap=cmap, symmetric=True, color="tec").relabel(f"old: N={old_pts}")
    + hv.Scatter(
        new["data"].to_dataframe(), kdims="x", vdims=["y", TECVAR]
    ).opts(size=5, cmap=cmap, symmetric=True, color=TECVAR).relabel(f"new {TECVAR}: N={new_pts}")
    + hv.Image(
        old["img"].image.where(old["img"].density > 0), kdims=["x", "y"], vdims="tec"
    ).opts(cmap=cmap, symmetric=True)
    + hv.Image(
        new["img"].image.where(new["img"].density > 0), kdims=["x", "y"], vdims=TECVAR
    ).opts(cmap=cmap, symmetric=True)
).cols(2)
# Out:
# INFO:gnss_tid.image:image boundary west: -2224.88
# INFO:gnss_tid.image:image boundary south: -1326.55
# INFO:gnss_tid.image:image boundary east: 2231.40
# INFO:gnss_tid.image:image boundary north: 1614.67
# INFO:gnss_tid.image:computed epsilon: 0.03
# :Layout
#    .Scatter.Old_colon_N_equals_11208       :Scatter   [x]   (y,tec)
#    .Scatter.New_dtecp_colon_N_equals_10739 :Scatter   [x]   (y,dtecp)
#    .Image.I                                :Image   [x,y]   (tec)
#    .Image.II                               :Image   [x,y]   (dtecp)
