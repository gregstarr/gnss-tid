# %%
import numpy as np
from gnss_tid.simulation_3d import ShellGrid, SimulationScenario

# %%
grid = ShellGrid(
    altitudes=300,
    res_lat=.1,
    res_lon=.1,
    lat_range=[24, 48],
    lon_range=[-120, -75],
)
sim = SimulationScenario(grid)
sim.generate_observation_table()
